# %%
import pandas as pd

df = pd.read_csv('/Users/lekhni/Downloads/BlackFriday.csv')

# %%
df['Age'].unique()
# Out:
# array(['0-17', '55+', '26-35', '46-50', '51-55', '36-45', '18-25'],
#       dtype=object)

# %%
age_dict = {
    '0-17': 0,
    '18-25': 1,
    '26-35': 2,
    '36-45': 3,
    '46-50': 4,
    '51-55': 5,
    '55+': 6
    }

# %%
df['Gender'].unique()
# Out:
# array(['F', 'M'], dtype=object)

# %%
gender_dict = {'F': 0, 'M': 1}

# %%
df['City_Category'].unique()
# Out:
# array(['A', 'C', 'B'], dtype=object)

# %%
city_category_dict = {'A': 1, 'B': 2, 'C': 3}

# %%
df['Stay_In_Current_City_Years'].unique()
# Out:
# array(['2', '4+', '3', '1', '0'], dtype=object)

# %%
Stay_In_Current_City_Years_dict = {'0': 0, '1': 1, '2': 2, '3': 3, '4+': 4}

# %%
df['Marital_Status'].unique()
# Out:
# array([0, 1])

# %%
df['Product_Category_1'].unique()
# Out:
# array([ 3,  1, 12,  8,  5,  4,  2,  6, 14, 11, 13, 15,  7, 16, 18, 10, 17,
#         9])

# %%
df.loc[df['Age'] == '0-17']
# Out:
#         User_ID Product_ID Gender   Age  Occupation City_Category  \
# 0       1000001  P00069042      F  0-17          10             A
# 1       1000001  P00248942      F  0-17          10             A
# 2       1000001  P00087842      F  0-17          10             A
# 3       1000001  P00085442      F  0-17          10             A
# 85      1000019  P00112542      M  0-17          10             A
# 86      1000019  P00339542      M  0-17          10             A
# 87      1000019  P00127842      M  0-17          10             A
# 88      1000019  P00125942      M  0-17          10             A
# 89      1000019  P00251342      M  0-17          10             A
# 90      1000019  P00249642      M  0-17          10             A
# 91      1000019  P00124842      M  0-17          10             A
# 92      1000019  P00250642      M  0-17          10             A
# 93      1000019  P00058142      M  0-17          10             A
# ...

# %%
df.loc['Age', '0-17'] = 0

# %%
df
# Out:
#           User_ID Product_ID Gender    Age  Occupation City_Category  \
# 0       1000001.0  P00069042      F   0-17        10.0             A
# 1       1000001.0  P00248942      F   0-17        10.0             A
# 2       1000001.0  P00087842      F   0-17        10.0             A
# 3       1000001.0  P00085442      F   0-17        10.0             A
# 4       1000002.0  P00285442      M    55+        16.0             C
# 5       1000003.0  P00193542      M  26-35        15.0             A
# 6       1000004.0  P00184942      M  46-50         7.0             B
# 7       1000004.0  P00346142      M  46-50         7.0             B
# 8       1000004.0   P0097242      M  46-50         7.0             B
# 9       1000005.0  P00274942      M  26-35        20.0             A
# 10      1000005.0  P00251242      M  26-35        20.0             A
# 11      1000005.0  P00014542      M  26-35        20.0             A
# 12      1000005.0  P00031342      M  26-35        20.0             A
# ...
